# %% [markdown]
# # Part-1: GDP Analysis of Indian States

# %% [markdown]
# ## Part 1A

# %% [markdown]
# ### importing libraries and csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/User/Desktop/practice set/GDP Analysis/copy data 1A/ab40c054-5031-4376-b52e-9813e776f65e.csv')
df.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# ...

# %% [markdown]
# ### setting Duration as index

# %%
df.set_index('Duration', inplace = True)
df.head()
# Out:
#                           Items  Description  Andhra Pradesh   \
# Duration
# 2011-12   GSDP - CURRENT PRICES (` in Crore)         379402.0
# 2012-13   GSDP - CURRENT PRICES (` in Crore)         411404.0
# 2013-14   GSDP - CURRENT PRICES (` in Crore)         464272.0
# 2014-15   GSDP - CURRENT PRICES (` in Crore)         526468.0
# 2015-16   GSDP - CURRENT PRICES (` in Crore)         609934.0
#
#           Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa  \
# Duration
# 2011-12             11063.0  143175.0  247144.0      158074.0  42367.0
# 2012-13             12547.0  156864.0  282368.0      177511.0  38120.0
# 2013-14             14602.0  177745.0  317101.0      206690.0  35921.0
# 2014-15             16761.0  198098.0  373920.0      234982.0  40633.0
# 2015-16             18784.0  224234.0  413503.0      260776.0  45002.0
#
#            Gujarat   Haryana  Himachal Pradesh      ...        Telangana  \
# Duration                                            ...
# ...

# %% [markdown]
# ### Transposing dataframe

# %%
transpose_df = df.T
transpose_df.head()
# Out:
# Duration                                       2011-12  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  379402
# Arunachal Pradesh                                11063
# Assam                                           143175
# Bihar                                           247144
#
# Duration                                       2012-13  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  411404
# Arunachal Pradesh                                12547
# Assam                                           156864
# Bihar                                           282368
#
# Duration                                       2013-14  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  464272
# Arunachal Pradesh                                14602
# Assam                                           177745
# ...

# %% [markdown]
# ### Removing the rows: '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (' in Crore)' for the year 2016-17

# %%
df_1 = transpose_df.loc[:,[True,True,True,True,True,False,True,True,True,True,False]]
df_1.head()
# Out:
# Duration                                       2011-12  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  379402
# Arunachal Pradesh                                11063
# Assam                                           143175
# Bihar                                           247144
#
# Duration                                       2012-13  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  411404
# Arunachal Pradesh                                12547
# Assam                                           156864
# Bihar                                           282368
#
# Duration                                       2013-14  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  464272
# Arunachal Pradesh                                14602
# Assam                                           177745
# ...

# %% [markdown]
# ### Analysing the Null Values

# %%
df_1.isnull()
# Out:
# Duration                   2011-12  2012-13  2013-14  2014-15  2015-16  \
# Items  Description           False    False    False    False    False
# Andhra Pradesh               False    False    False    False    False
# Arunachal Pradesh            False    False    False    False    False
# Assam                        False    False    False    False    False
# Bihar                        False    False    False    False    False
# Chhattisgarh                 False    False    False    False    False
# Goa                          False    False    False    False    False
# Gujarat                      False    False    False    False    False
# Haryana                      False    False    False    False    False
# Himachal Pradesh             False    False    False    False     True
# Jammu & Kashmir              False    False    False    False    False
# Jharkhand                    False    False    False    False    False
# ...

# %%
df_1.isnull().sum()
# Out:
# Duration
# 2011-12     1
# 2012-13     1
# 2013-14     1
# 2014-15     1
# 2015-16    10
# 2012-13     1
# 2013-14     1
# 2014-15     1
# 2015-16    10
# dtype: int64

# %%
df.isnull().any(axis=0)
# Out:
# Items  Description           False
# Andhra Pradesh               False
# Arunachal Pradesh             True
# Assam                         True
# Bihar                         True
# Chhattisgarh                 False
# Goa                           True
# Gujarat                       True
# Haryana                      False
# Himachal Pradesh              True
# Jammu & Kashmir               True
# Jharkhand                     True
# Karnataka                     True
# Kerala                        True
# Madhya Pradesh               False
# Maharashtra                   True
# Manipur                       True
# Meghalaya                    False
# Mizoram                       True
# Nagaland                      True
# Odisha                       False
# Punjab                        True
# Rajasthan                     True
# Sikkim                        True
# Tamil Nadu                   False
# Telangana                    False
# Tripura                       True
# ...

# %%
df.isnull().all(axis=0)
# Out:
# Items  Description           False
# Andhra Pradesh               False
# Arunachal Pradesh            False
# Assam                        False
# Bihar                        False
# Chhattisgarh                 False
# Goa                          False
# Gujarat                      False
# Haryana                      False
# Himachal Pradesh             False
# Jammu & Kashmir              False
# Jharkhand                    False
# Karnataka                    False
# Kerala                       False
# Madhya Pradesh               False
# Maharashtra                  False
# Manipur                      False
# Meghalaya                    False
# Mizoram                      False
# Nagaland                     False
# Odisha                       False
# Punjab                       False
# Rajasthan                    False
# Sikkim                       False
# Tamil Nadu                   False
# Telangana                    False
# Tripura                      False
# ...

# %%
round(100*(df_1.isnull().sum()/len(df_1.index)), 2)
# Out:
# Duration
# 2011-12     2.86
# 2012-13     2.86
# 2013-14     2.86
# 2014-15     2.86
# 2015-16    28.57
# 2012-13     2.86
# 2013-14     2.86
# 2014-15     2.86
# 2015-16    28.57
# dtype: float64

# %% [markdown]
# ### Calculate the average growth of the states over the duration 2013-14, 2014-15, and 2015-16 by taking mean of the row '(% Growth over previous year)'.<br>Compare the calculated value and plot it for the states.

# %%
df_2 = df_1.iloc[:, 6:]
df_2.head()
# Out:
# Duration                                  2013-14  \
# Items  Description  (% Growth over previous year)
# Andhra Pradesh                              12.85
# Arunachal Pradesh                           16.38
# Assam                                       13.31
# Bihar                                        12.3
#
# Duration                                  2014-15  \
# Items  Description  (% Growth over previous year)
# Andhra Pradesh                               13.4
# Arunachal Pradesh                           14.79
# Assam                                       11.45
# Bihar                                       17.92
#
# Duration                                  2015-16
# Items  Description  (% Growth over previous year)
# Andhra Pradesh                              15.85
# Arunachal Pradesh                           12.07
# Assam                                       13.19
# Bihar                                       10.59

# %%
df_2.isnull().sum()
# Out:
# Duration
# 2013-14     1
# 2014-15     1
# 2015-16    10
# dtype: int64

# %%
df_2.loc[:,:].describe()
# Out:
# Duration  2013-14  2014-15  2015-16
# count       34.00    34.00    25.00
# unique      34.00    33.00    25.00
# top         14.91    10.14    10.99
# freq         1.00     2.00     1.00

# %%
df_2 = df_2.iloc[1:,:]
df_2.head()
# Out:
# Duration          2013-14 2014-15 2015-16
# Andhra Pradesh      12.85    13.4   15.85
# Arunachal Pradesh   16.38   14.79   12.07
# Assam               13.31   11.45   13.19
# Bihar                12.3   17.92   10.59
# Chhattisgarh        16.44   13.69   10.98

# %%
df_2.mean()
# Out:
# Duration
# 2013-14    13.564242
# 2014-15    11.408788
# 2015-16    11.457083
# dtype: float64

# %% [markdown]
# #### imputing the NaN values with the mean

# %%
df_2 = df_2.fillna(df_2.mean())

# %%
df_2.head(35)
# Out:
# Duration                     2013-14    2014-15    2015-16
# Andhra Pradesh             12.850000  13.400000  15.850000
# Arunachal Pradesh          16.380000  14.790000  12.070000
# Assam                      13.310000  11.450000  13.190000
# Bihar                      12.300000  17.920000  10.590000
# Chhattisgarh               16.440000  13.690000  10.980000
# Goa                        -5.770000  13.120000  10.750000
# Gujarat                    11.470000  10.820000  11.090000
# Haryana                    15.450000   9.180000  10.910000
# Himachal Pradesh           14.420000  10.140000  11.457083
# Jammu & Kashmir            10.090000   4.700000  17.910000
# Jharkhand                   7.920000  15.140000  11.440000
# Karnataka                  18.240000  12.700000  11.420000
# Kerala                     12.790000  13.110000  11.850000
# Madhya Pradesh             14.910000  10.110000  12.860000
# Maharashtra                13.740000   8.780000  11.457083
# ...

# %% [markdown]
# #### calculated mean of the states over the duration 2013-14, 2014-15, 2015-16

# %%
avg_df = pd.DataFrame(df_2.mean(axis=1))

# %%
avg_df.head(35)
# Out:
#                                    0
# Andhra Pradesh             14.033333
# Arunachal Pradesh          14.413333
# Assam                      12.650000
# Bihar                      13.603333
# Chhattisgarh               13.703333
# Goa                         6.033333
# Gujarat                    11.126667
# Haryana                    11.846667
# Himachal Pradesh           12.005694
# Jammu & Kashmir            10.900000
# Jharkhand                  11.500000
# Karnataka                  14.120000
# Kerala                     12.583333
# Madhya Pradesh             12.626667
# Maharashtra                11.325694
# Manipur                    13.559028
# Meghalaya                   6.953333
# Mizoram                    15.619028
# Nagaland                   14.762361
# Odisha                      9.836667
# Punjab                     11.275694
# Rajasthan                  11.365694
# Sikkim                     10.486667
# Tamil Nadu                 12.336667
# ...

# %% [markdown]
# #### sorting the mean value in descending order

# %%
avg_df[0].sort_values(ascending = False)
# Out:
# Mizoram                      15.619028
# Tripura                      15.172361
# Nagaland                     14.762361
# Arunachal Pradesh            14.413333
# Karnataka                    14.120000
# Andhra Pradesh               14.033333
# Chhattisgarh                 13.703333
# Bihar                        13.603333
# Manipur                      13.559028
# Andaman & Nicobar Islands    13.009028
# Telangana                    12.763333
# Assam                        12.650000
# Madhya Pradesh               12.626667
# Kerala                       12.583333
# Tamil Nadu                   12.336667
# Delhi                        12.160000
# West Bengal1                 12.143371
# Puducherry                   12.053333
# Himachal Pradesh             12.005694
# Chandigarh                   11.960000
# Uttar Pradesh                11.940000
# Haryana                      11.846667
# Uttarakhand                  11.803333
# Jharkhand                    11.500000
# ...

# %%
df_temp = pd.DataFrame(avg_df[0].sort_values(ascending = False))

# %%
df_temp.head()
# Out:
#                            0
# Mizoram            15.619028
# Tripura            15.172361
# Nagaland           14.762361
# Arunachal Pradesh  14.413333
# Karnataka          14.120000

# %% [markdown]
# ### Comparing the average growth rate of the states using bar plot

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 0, y = df_temp.index, data = df_temp)
plt.xlabel('Average')
plt.ylabel('States')
plt.show()

# %% [markdown]
# ### Which states have been growing consistently fast, and which ones have been struggling?

# %% [markdown]
# #### States which have been growing consistently are:
# - Mizoram
# - Tripura
# - Nagaland
# - Arunachal Pradesh
# - Karnataka
#
# #### States which have been struggling are:
# - Goa
# - Meghalaya
# - Odisha
# - Sikkim
# - Jammu & Kashmir

# %% [markdown]
# ### Curiosity exercise - what has been the average growth rate of your home state, and how does it compare to the national average over this duration?

# %% [markdown]
# - Average growth rate of Uttar Pradesh is 11.940000
# - National growth rate is 11.203333

# %% [markdown]
# ### Plot the total GDP of the states for the year 2015-16

# %%
df.head()
# Out:
#                           Items  Description  Andhra Pradesh   \
# Duration
# 2011-12   GSDP - CURRENT PRICES (` in Crore)         379402.0
# 2012-13   GSDP - CURRENT PRICES (` in Crore)         411404.0
# 2013-14   GSDP - CURRENT PRICES (` in Crore)         464272.0
# 2014-15   GSDP - CURRENT PRICES (` in Crore)         526468.0
# 2015-16   GSDP - CURRENT PRICES (` in Crore)         609934.0
#
#           Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa  \
# Duration
# 2011-12             11063.0  143175.0  247144.0      158074.0  42367.0
# 2012-13             12547.0  156864.0  282368.0      177511.0  38120.0
# 2013-14             14602.0  177745.0  317101.0      206690.0  35921.0
# 2014-15             16761.0  198098.0  373920.0      234982.0  40633.0
# 2015-16             18784.0  224234.0  413503.0      260776.0  45002.0
#
#            Gujarat   Haryana  Himachal Pradesh      ...        Telangana  \
# Duration                                            ...
# ...

# %%
df_3 = df.T
df_3.head()
# Out:
# Duration                                       2011-12  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  379402
# Arunachal Pradesh                                11063
# Assam                                           143175
# Bihar                                           247144
#
# Duration                                       2012-13  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  411404
# Arunachal Pradesh                                12547
# Assam                                           156864
# Bihar                                           282368
#
# Duration                                       2013-14  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  464272
# Arunachal Pradesh                                14602
# Assam                                           177745
# ...

# %% [markdown]
# #### slicing only GSDP - CURRENT PRICES (` in Crore) for the year 2015-16

# %%
df_3 = df_3.loc[:,['2015-16']]
df_3.head()
# Out:
# Duration                                       2015-16  \
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  609934
# Arunachal Pradesh                                18784
# Assam                                           224234
# Bihar                                           413503
#
# Duration                                  2015-16
# Items  Description  (% Growth over previous year)
# Andhra Pradesh                              15.85
# Arunachal Pradesh                           12.07
# Assam                                       13.19
# Bihar                                       10.59

# %%
df_3 = df_3.iloc[1:,[True]]
df_3.head()
# Out:
# Duration          2015-16
# Andhra Pradesh     609934
# Arunachal Pradesh   18784
# Assam              224234
# Bihar              413503
# Chhattisgarh       260776

# %% [markdown]
# #### sorting data in Descending order

# %%
df_Desc = pd.DataFrame(df_3.sort_values(by='2015-16', ascending = False))
df_Desc.head(6)
# Out:
# Duration             2015-16
# All_India GDP    1.36753e+07
# Tamil Nadu       1.21267e+06
# Uttar Pradesh     1.1538e+06
# Karnataka        1.02707e+06
# Gujarat               994316
# Andhra Pradesh        609934

# %% [markdown]
# ### Top 5 states based on total GDP are:
# - Tamil Nadu
# - Uttar Pradesh
# - Karnataka
# - Gujarat
# - Andra Pradesh

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = '2015-16', y = df_Desc.index, data = df_Desc)
plt.xlabel('GDP (2015-16)')
plt.ylabel('States')
plt.show()

# %% [markdown]
# #### sorting data in Acsending order

# %%
df_Asc = pd.DataFrame(df_3.sort_values(by='2015-16', ascending = True))
df_Asc.head()
# Out:
# Duration          2015-16
# Sikkim              16637
# Arunachal Pradesh   18784
# Puducherry          26533
# Meghalaya           26745
# Chandigarh          30304

# %% [markdown]
# ### Bottom 5 states based on total GDP are:
# - Sikkim
# - Arunachal Pradesh
# - Puducherry
# - Meghalaya
# - Chandigarh

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = '2015-16', y = df_Asc.index, data = df_Asc)
plt.xlabel('GDP (2015-16)')
plt.ylabel('States')
plt.show()

# %% [markdown]
# ## Part 1B

# %% [markdown]
# #### Merging all the dataset of 1B

# %%
import glob
path = 'C:/Users/User/Desktop/practice set/GDP Analysis/copy data 1B'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col = None, header = 0, encoding = 'ISO-8859-1')
    df['States'] = filename.split('-')[1]
    li.append(df)
    
GSVA_df = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
GSVA_df.head()
# Out:
#   S.No.                               Item    2011-12     2012-13     2013-14  \
# 0     1  Agriculture, forestry and fishing  9400805.0  11186428.0  12895568.0
# 1   1.1                              Crops  5204052.0   6123041.0   7114707.0
# 2   1.2                          Livestock  2758776.0   3358438.0   3643026.0
# 3   1.3               Forestry and logging   250314.0    253029.0    280493.0
# 4   1.4            Fishing and aquaculture  1187663.0   1451920.0   1857342.0
#
#       2014-15     2015-16     2016-17          States
# 0  14819416.0  17326726.0  20386004.0  Andhra_Pradesh
# 1   7893514.0   8644285.0   9717089.0  Andhra_Pradesh
# 2   4309078.0   5155487.0   5979648.0  Andhra_Pradesh
# 3    346160.0    340550.0    335487.0  Andhra_Pradesh
# 4   2270664.0   3186404.0   4353780.0  Andhra_Pradesh

# %% [markdown]
# #### getting data for the duration 2014-15

# %%
df_1 = GSVA_df.loc[:,[False, True, False, False, False, True, False, False, True]]
df_1.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_1.isnull().sum()
# Out:
# Item        0
# 2014-15    16
# States      0
# dtype: int64

# %% [markdown]
# #### imputing the NaN values with it's mean

# %%
df_1 = df_1.fillna(df_1.mean())
df_1.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_1.isnull().sum()
# Out:
# Item       0
# 2014-15    0
# States     0
# dtype: int64

# %% [markdown]
# #### setting Item as an index

# %%
df_1.set_index('Item',inplace = True)
df_1.head()
# Out:
#                                       2014-15          States
# Item
# Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# Crops                               7893514.0  Andhra_Pradesh
# Livestock                           4309078.0  Andhra_Pradesh
# Forestry and logging                 346160.0  Andhra_Pradesh
# Fishing and aquaculture             2270664.0  Andhra_Pradesh

# %% [markdown]
# ### Getting GDP per capita for all the states

# %%
df_2 = df_1.loc['Per Capita GSDP (Rs.)',:]
df_2.head()
# Out:
#                         2014-15             States
# Item
# Per Capita GSDP (Rs.)  104977.0     Andhra_Pradesh
# Per Capita GSDP (Rs.)  112718.0  Arunachal_Pradesh
# Per Capita GSDP (Rs.)   60621.0              Assam
# Per Capita GSDP (Rs.)   33954.0              Bihar
# Per Capita GSDP (Rs.)   86860.0       Chhattisgarh

# %% [markdown]
# #### sorting in Descending order

# %%
df_2 = pd.DataFrame(df_2.sort_values(by='2014-15', ascending = False))
df_2.head(6)
# Out:
#                         2014-15       States
# Item
# Per Capita GSDP (Rs.)  271793.0          Goa
# Per Capita GSDP (Rs.)  240274.0       Sikkim
# Per Capita GSDP (Rs.)  164077.0      Haryana
# Per Capita GSDP (Rs.)  154778.0       Kerala
# Per Capita GSDP (Rs.)  153076.0  Uttarakhand
# Per Capita GSDP (Rs.)  152853.0  Maharashtra

# %%
df_2.tail()
# Out:
#                        2014-15         States
# Item
# Per Capita GSDP (Rs.)  62091.0      Jharkhand
# Per Capita GSDP (Rs.)  60621.0          Assam
# Per Capita GSDP (Rs.)  58442.0        Manipur
# Per Capita GSDP (Rs.)  49450.0  Uttar_Pradesh
# Per Capita GSDP (Rs.)  33954.0          Bihar

# %% [markdown]
# ### Plot the GDP per capita for all the states

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='2014-15', y='States', data=df_2)
plt.title('Per Capita GSDP(Rs.)')
plt.show()

# %% [markdown]
# ### Identify the top-5 and the bottom-5 states based on GDP per capita
# #### Top 5 States:
# - Goa
# - Sikkim
# - Haryana
# - Kerala
# - Uttrakhand
#
# #### Bottom 5 States:
# - Bihar
# - Uttar_Pradesh
# - Manipur
# - Assam
# - Jharkhand

# %% [markdown]
# ### Find the ratio of highest per capita GDP to the lowest per capita GDP

# %%
271793.0/33954.0
# Out:
# 8.004741709371503

# %% [markdown]
# ### Plot the percentage contribution of primary, secondary and tertiary sectors as a percentage of total GDP for all the states.

# %%
GSVA_df.head()
# Out:
#   S.No.                               Item    2011-12     2012-13     2013-14  \
# 0     1  Agriculture, forestry and fishing  9400805.0  11186428.0  12895568.0
# 1   1.1                              Crops  5204052.0   6123041.0   7114707.0
# 2   1.2                          Livestock  2758776.0   3358438.0   3643026.0
# 3   1.3               Forestry and logging   250314.0    253029.0    280493.0
# 4   1.4            Fishing and aquaculture  1187663.0   1451920.0   1857342.0
#
#       2014-15     2015-16     2016-17          States
# 0  14819416.0  17326726.0  20386004.0  Andhra_Pradesh
# 1   7893514.0   8644285.0   9717089.0  Andhra_Pradesh
# 2   4309078.0   5155487.0   5979648.0  Andhra_Pradesh
# 3    346160.0    340550.0    335487.0  Andhra_Pradesh
# 4   2270664.0   3186404.0   4353780.0  Andhra_Pradesh

# %%
df_3 = GSVA_df.loc[:,[False, True, False, False, False, True, False, False, True]]
df_3.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %% [markdown]
# #### imputing the missing values

# %%
df_3 = df_3.fillna(df_3.mean())
df_3.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_3 = df_3.pivot_table(index = 'States', columns = 'Item', values = '2014-15')
df_3.head()
# Out:
# Item               Agriculture, forestry and fishing  Air transport  \
# States
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chhattisgarh                               3948847.0         9507.0
#
# Item               Communication & services related to broadcasting  \
# States
# Andhra_Pradesh                                             928756.0
# Arunachal_Pradesh                                           19568.0
# Assam                                                      357619.0
# Bihar                                                      919427.0
# Chhattisgarh                                               294552.0
#
# Item               Construction      Crops  \
# States
# Andhra_Pradesh        4664889.0  7893514.0
# ...

# %%
GSDP_Series = df_3['Gross State Domestic Product'].values

# %%
GSDP_Series
# Out:
# array([5.26468420e+07, 1.67611900e+06, 1.98098000e+07, 3.73919880e+07,
#        2.34981800e+07, 4.06330700e+06, 8.95027270e+07, 4.37462070e+07,
#        1.04368790e+07, 2.17107180e+07, 9.21788060e+07, 5.26002300e+07,
#        4.81981690e+07, 1.79212165e+08, 1.80427600e+06, 2.44080700e+06,
#        1.15593300e+06, 1.84142400e+06, 3.21970920e+07, 3.68010890e+07,
#        6.12194470e+07, 1.52093300e+06, 1.09256373e+08, 5.11177650e+07,
#        2.96666200e+06, 1.04337115e+08, 1.61985290e+07])

# %%
df_3 = df_3.loc[:,['Primary', 'Secondary', 'Tertiary']]
df_3.head()
# Out:
# Item                  Primary   Secondary    Tertiary
# States
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0
# Assam               5326697.0   4033091.0   9307109.0
# Bihar               8019997.0   5984896.0  22179969.0
# Chhattisgarh        6400817.0   8238886.0   7588778.0

# %%
df_3 = df_3.div(GSDP_Series, axis = 0)
df_3.head()
# Out:
# Item                Primary  Secondary  Tertiary
# States
# Andhra_Pradesh     0.309681   0.199231  0.418505
# Arunachal_Pradesh  0.427749   0.171521  0.376968
# Assam              0.268892   0.203591  0.469823
# Bihar              0.214484   0.160058  0.593174
# Chhattisgarh       0.272396   0.350618  0.322952

# %% [markdown]
# #### calculating percentage contribution of primary, secondary and tertiary of total GDP for all the states

# %%
df_3 = df_3*100
df_3.head()
# Out:
# Item                 Primary  Secondary   Tertiary
# States
# Andhra_Pradesh     30.968080  19.923102  41.850453
# Arunachal_Pradesh  42.774946  17.152064  37.696846
# Assam              26.889201  20.359070  46.982347
# Bihar              21.448437  16.005825  59.317437
# Chhattisgarh       27.239629  35.061805  32.295173

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_3, cmap='YlGnBu', annot=True)
plt.show()

# %% [markdown]
# ### Categorise the states into four categories based on GDP per capita (C1, C2, C3, C4 - C1 would have the highest per capita GDP, C4 the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e. the states lying between the 85th and the 100th percentile are in C1, those between 50th and 85th percentile are in C2 and so on.

# %%
GSVA_df.head()
# Out:
#   S.No.                               Item    2011-12     2012-13     2013-14  \
# 0     1  Agriculture, forestry and fishing  9400805.0  11186428.0  12895568.0
# 1   1.1                              Crops  5204052.0   6123041.0   7114707.0
# 2   1.2                          Livestock  2758776.0   3358438.0   3643026.0
# 3   1.3               Forestry and logging   250314.0    253029.0    280493.0
# 4   1.4            Fishing and aquaculture  1187663.0   1451920.0   1857342.0
#
#       2014-15     2015-16     2016-17          States
# 0  14819416.0  17326726.0  20386004.0  Andhra_Pradesh
# 1   7893514.0   8644285.0   9717089.0  Andhra_Pradesh
# 2   4309078.0   5155487.0   5979648.0  Andhra_Pradesh
# 3    346160.0    340550.0    335487.0  Andhra_Pradesh
# 4   2270664.0   3186404.0   4353780.0  Andhra_Pradesh

# %%
df_4 = GSVA_df.loc[:,[False, True, False, False, False, True, False, False, True]]
df_4.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_4 = df_4.fillna(df_4.mean())
df_4.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_4.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_4 = df_4.pivot_table(index = 'States', columns = 'Item', values = '2014-15')
df_4.head()
# Out:
# Item               Agriculture, forestry and fishing  Air transport  \
# States
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chhattisgarh                               3948847.0         9507.0
#
# Item               Communication & services related to broadcasting  \
# States
# Andhra_Pradesh                                             928756.0
# Arunachal_Pradesh                                           19568.0
# Assam                                                      357619.0
# Bihar                                                      919427.0
# Chhattisgarh                                               294552.0
#
# Item               Construction      Crops  \
# States
# Andhra_Pradesh        4664889.0  7893514.0
# ...

# %% [markdown]
# #### getting the values of Per Capita GSDP (Rs.) in the form of series

# %%
GDP_PerCaptia_Series = df_4['Per Capita GSDP (Rs.)'].values
GDP_PerCaptia_Series
# Out:
# array([104977., 112718.,  60621.,  33954.,  86860., 271793., 141263.,
#        164077., 147330.,  62091., 145141., 154778.,  62989., 152853.,
#         58442.,  76228.,  97687.,  89607.,  73979., 126606.,  84837.,
#        240274., 146503., 139035.,  77358.,  49450., 153076.])

# %% [markdown]
# #### creating quantile column and categorizing each states based on C1, C2, C3 and C4 where C1 would have the highest per capita GDP and C4 the lowest

# %%
df_4['quantile'] = pd.qcut(GDP_PerCaptia_Series, [0, 0.20, 0.5, 0.85, 1], labels = ['C4', 'C3', 'C2', 'C1'])

# %%
df_4.head()
# Out:
# Item               Agriculture, forestry and fishing  Air transport  \
# States
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chhattisgarh                               3948847.0         9507.0
#
# Item               Communication & services related to broadcasting  \
# States
# Andhra_Pradesh                                             928756.0
# Arunachal_Pradesh                                           19568.0
# Assam                                                      357619.0
# Bihar                                                      919427.0
# Chhattisgarh                                               294552.0
#
# Item               Construction      Crops  \
# States
# Andhra_Pradesh        4664889.0  7893514.0
# ...

# %%
Quantile_States = pd.DataFrame(df_4.loc[:,'quantile'])
Quantile_States
# Out:
#                   quantile
# States
# Andhra_Pradesh          C3
# Arunachal_Pradesh       C2
# Assam                   C4
# Bihar                   C4
# Chhattisgarh            C3
# Goa                     C1
# Gujarat                 C2
# Haryana                 C1
# Himachal_Pradesh        C2
# Jharkhand               C4
# Karnataka               C2
# Kerala                  C1
# Madhya_Pradesh          C4
# Maharashtra             C2
# Manipur                 C4
# Meghalaya               C3
# Mizoram                 C3
# Nagaland                C3
# Odisha                  C3
# Punjab                  C2
# Rajasthan               C3
# Sikkim                  C1
# Tamil_Nadu              C2
# Telangana               C2
# Tripura                 C3
# Uttar_Pradesh           C4
# Uttarakhand             C2

# %% [markdown]
# #### States which are under C1 categories

# %%
C1_States = Quantile_States.loc[Quantile_States['quantile'] == 'C1']
C1_States
# Out:
#         quantile
# States
# Goa           C1
# Haryana       C1
# Kerala        C1
# Sikkim        C1

# %% [markdown]
# #### States which are under C2 categories

# %%
C2_States = Quantile_States.loc[Quantile_States['quantile'] == 'C2']
C2_States
# Out:
#                   quantile
# States
# Arunachal_Pradesh       C2
# Gujarat                 C2
# Himachal_Pradesh        C2
# Karnataka               C2
# Maharashtra             C2
# Punjab                  C2
# Tamil_Nadu              C2
# Telangana               C2
# Uttarakhand             C2

# %% [markdown]
# #### States which are under C3 categories

# %%
C3_States = Quantile_States.loc[Quantile_States['quantile'] == 'C3']
C3_States
# Out:
#                quantile
# States
# Andhra_Pradesh       C3
# Chhattisgarh         C3
# Meghalaya            C3
# Mizoram              C3
# Nagaland             C3
# Odisha               C3
# Rajasthan            C3
# Tripura              C3

# %% [markdown]
# #### States which are under C4 categories

# %%
C4_States = Quantile_States.loc[Quantile_States['quantile'] == 'C4']
C4_States
# Out:
#                quantile
# States
# Assam                C4
# Bihar                C4
# Jharkhand            C4
# Madhya_Pradesh       C4
# Manipur              C4
# Uttar_Pradesh        C4

# %% [markdown]
# ### Find the top 3/4/5 sub-sectors (such as agriculture, forestry and fishing, crops, manufacturing etc.) [not primary, secondary and tertiary] which contribute to approx. 80% of the GSDP of each category

# %%
df_4.head()
# Out:
# Item               Agriculture, forestry and fishing  Air transport  \
# States
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chhattisgarh                               3948847.0         9507.0
#
# Item               Communication & services related to broadcasting  \
# States
# Andhra_Pradesh                                             928756.0
# Arunachal_Pradesh                                           19568.0
# Assam                                                      357619.0
# Bihar                                                      919427.0
# Chhattisgarh                                               294552.0
#
# Item               Construction      Crops  \
# States
# Andhra_Pradesh        4664889.0  7893514.0
# ...

# %% [markdown]
# #### groupby Quantile and its plot sub-sector wise

# %%
df_4=df_4.drop(columns=['Crops','Air transport','Forestry and logging','Fishing and aquaculture','Livestock','Primary','Secondary','Trade & repair services','Hotels & restaurants','Railways','Road transport','Water transport','Services incidental to transport','Storage','Communication & services related to broadcasting','Tertiary','TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products','Per Capita GSDP (Rs.)'],axis=1)
df_4
# Out:
# Item               Agriculture, forestry and fishing  Construction  \
# States
# Andhra_Pradesh                            14819416.0     4664889.0
# Arunachal_Pradesh                           686117.0      147842.0
# Assam                                      3855548.0     1733568.0
# Bihar                                      7951890.0     3449763.0
# Chhattisgarh                               3948847.0     2669855.0
# Goa                                         308507.0      165819.0
# Gujarat                                   13769969.0     5526017.0
# Haryana                                    8015238.0     3702571.0
# Himachal_Pradesh                           1514981.0      808256.0
# Jharkhand                                  3211065.0     1789834.0
# Karnataka                                 11219422.0     6104799.0
# Kerala                                     5930617.0     7314003.0
# Madhya_Pradesh                            16235647.0     4403151.0
# ...

# %%
df_4=df_4.drop(columns=['Road transport*','Road transport**','Services incidental to transport*','Trade & repair services*',],axis=1)
df_4
# Out:
# Item               Agriculture, forestry and fishing  Construction  \
# States
# Andhra_Pradesh                            14819416.0     4664889.0
# Arunachal_Pradesh                           686117.0      147842.0
# Assam                                      3855548.0     1733568.0
# Bihar                                      7951890.0     3449763.0
# Chhattisgarh                               3948847.0     2669855.0
# Goa                                         308507.0      165819.0
# Gujarat                                   13769969.0     5526017.0
# Haryana                                    8015238.0     3702571.0
# Himachal_Pradesh                           1514981.0      808256.0
# Jharkhand                                  3211065.0     1789834.0
# Karnataka                                 11219422.0     6104799.0
# Kerala                                     5930617.0     7314003.0
# Madhya_Pradesh                            16235647.0     4403151.0
# ...

# %%
sub_category=['category','Agriculture, forestry and fishing','Mining and quarrying','Manufacturing','Electricity, gas, water supply & other utility services','Construction','Trade, repair, hotels and restaurants','Transport, storage, communication & services related to broadcasting','Financial services','Real estate, ownership of dwelling & professional services','Public administration','Other services','Gross State Domestic Product']
sub_category
# Out:
# ['category',
#  'Agriculture, forestry and fishing',
#  'Mining and quarrying',
#  'Manufacturing',
#  'Electricity, gas, water supply & other utility services',
#  'Construction',
#  'Trade, repair, hotels and restaurants',
#  'Transport, storage, communication & services related to broadcasting',
#  'Financial services',
#  'Real estate, ownership of dwelling & professional services',
#  'Public administration',
#  'Other services',
#  'Gross State Domestic Product']

# %%
df_4= df4.loc[:, sub_category]
df_4

# %%
df_4['%Agriculture']= ((df_4['Agriculture, forestry and fishing']) / (df_4['Gross State Domestic Product']))*100
df_4['%Mining and quarrying']= ((df_4['Mining and quarrying']) / (df_4['Gross State Domestic Product']))*100
df_4['%Manufacturing']= ((df_4['Manufacturing']) / (df_4['Gross State Domestic Product']))*100
df_4['%Electricity, gas, water supply & other utility services']= ((df_4['Electricity, gas, water supply & other utility services']) / (df_4['Gross State Domestic Product']))*100
df_4['%Construction']= ((df_4['Construction']) / (df_4['Gross State Domestic Product']))*100
df_4['%Trade, repair, hotels and restaurants']= ((df_4['Trade, repair, hotels and restaurants']) / (df_4['Gross State Domestic Product']))*100
df_4['%Transport, storage, communication & services related to broadcasting']= ((df_4['Transport, storage, communication & services related to broadcasting']) / (df_4['Gross State Domestic Product']))*100
df_4['%Financial services']= ((df_4['Financial services']) / (df_4['Gross State Domestic Product']))*100
df_4['%Real estate, ownership of dwelling & professional services']= ((df_4['Real estate, ownership of dwelling & professional services']) / (df_4['Gross State Domestic Product']))*100
df_4['%Public administration']= ((df_4['Public administration']) / (df_4['Gross State Domestic Product']))*100
df_4['Other services']= ((df_4['Other services']) / (df_4['Gross State Domestic Product']))*100

df_4.head(500)
# Out:
# Item               Agriculture, forestry and fishing  Construction  \
# States
# Andhra_Pradesh                            14819416.0     4664889.0
# Arunachal_Pradesh                           686117.0      147842.0
# Assam                                      3855548.0     1733568.0
# Bihar                                      7951890.0     3449763.0
# Chhattisgarh                               3948847.0     2669855.0
# Goa                                         308507.0      165819.0
# Gujarat                                   13769969.0     5526017.0
# Haryana                                    8015238.0     3702571.0
# Himachal_Pradesh                           1514981.0      808256.0
# Jharkhand                                  3211065.0     1789834.0
# Karnataka                                 11219422.0     6104799.0
# Kerala                                     5930617.0     7314003.0
# Madhya_Pradesh                            16235647.0     4403151.0
# ...

# %%
df_by_quantile = df_4.groupby('quantile')
df_by_quantile

# %%
df_Agri = df_by_quantile['Agriculture, forestry and fishing'].sum()
df_Agri
# Out:
# quantile
# C4    56735044.0
# C3    42226888.0
# C2    75209022.0
# C1    14391809.0
# Name: Agriculture, forestry and fishing, dtype: float64

# %%
df_Agri.plot(kind='pie')
plt.show()

# %%
df_AirTransport = df_by_quantile['Air transport'].sum()
df_AirTransport
# Out:
# quantile
# C4    1.161540e+05
# C3    5.393312e+06
# C2    5.994183e+06
# C1    5.505730e+06
# Name: Air transport, dtype: float64

# %%
df_AirTransport.plot(kind='pie')
plt.show()

# %%
df_Communication = df_by_quantile['Communication & services related to broadcasting'].sum()
df_Communication
# Out:
# quantile
# C4    4462395.0
# C3    3050206.0
# C2    9408861.0
# C1    1420517.0
# Name: Communication & services related to broadcasting, dtype: float64

# %%
df_Communication.plot(kind='pie')
plt.show()

# %%
df_Construction = df_by_quantile['Construction'].sum()
df_Construction
# Out:
# quantile
# C4    22775948.0
# C3    15707921.0
# C2    40653562.0
# C1    11264451.0
# Name: Construction, dtype: float64

# %%
df_Construction.plot(kind='pie')
plt.show()

# %%
df_Crops = df_by_quantile['Crops'].sum()
df_Crops
# Out:
# quantile
# C4    39331055.0
# C3    23676317.0
# C2    47550095.0
# C1     7962514.0
# Name: Crops, dtype: float64

# %%
df_Crops.plot(kind='pie')
plt.show()

# %%
df_Utility = df_by_quantile['Electricity, gas, water supply & other utility services'].sum()
df_Utility
# Out:
# quantile
# C4     4310264.0
# C3     4604774.0
# C2    13823378.0
# C1     2000998.0
# Name: Electricity, gas, water supply & other utility services, dtype: float64

# %%
df_Utility.plot(kind='pie')
plt.show()

# %%
df_Finance = df_by_quantile['Financial services'].sum()
df_Finance
# Out:
# quantile
# C4     7684498.0
# C3     5766226.0
# C2    36296642.0
# C1     3936489.0
# Name: Financial services, dtype: float64

# %%
df_Finance.plot(kind='pie')
plt.show()

# %%
df_Fishing = df_by_quantile['Fishing and aquaculture'].sum()
df_Fishing
# Out:
# quantile
# C4    1828960.0
# C3    3368881.0
# C2    2691822.0
# C1     937204.0
# Name: Fishing and aquaculture, dtype: float64

# %%
df_Fishing.plot(kind='pie')
plt.show()

# %%
df_Forestry = df_by_quantile['Forestry and logging'].sum()
df_Forestry
# Out:
# quantile
# C4    3673623.0
# C3    4045895.0
# C2    5603213.0
# C1     872335.0
# Name: Forestry and logging, dtype: float64

# %%
df_Forestry.plot(kind='pie')
plt.show()

# %%
df_GSDP = df_by_quantile['Gross State Domestic Product'].sum()
df_GSDP
# Out:
# quantile
# C4    233252066.0
# C3    177966387.0
# C2    586380452.0
# C1    101930677.0
# Name: Gross State Domestic Product, dtype: float64

# %%
df_GSDP.plot(kind='pie')
plt.show()

# %%
df_Hotel = df_by_quantile['Hotels & restaurants'].sum()
df_Hotel
# Out:
# quantile
# C4    1.903356e+06
# C3    6.626303e+06
# C2    1.132087e+07
# C1    1.005412e+06
# Name: Hotels & restaurants, dtype: float64

# %%
df_Hotel.plot(kind='pie')
plt.show()

# %%
df_Livestock = df_by_quantile['Livestock'].sum()
df_Livestock
# Out:
# quantile
# C4    11901405.0
# C3    11135794.0
# C2    19363891.0
# C1     4619756.0
# Name: Livestock, dtype: float64

# %%
df_Livestock.plot(kind='pie')
plt.show()

# %%
df_Manufacturing = df_by_quantile['Manufacturing'].sum()
df_Manufacturing
# Out:
# quantile
# C4     24987032.0
# C3     22038331.0
# C2    109196530.0
# C1     13758793.0
# Name: Manufacturing, dtype: float64

# %%
df_Manufacturing.plot(kind='pie')
plt.show()

# %%
df_Mining = df_by_quantile['Mining and quarrying'].sum()
df_Mining
# Out:
# quantile
# C4    1.143076e+07
# C3    1.083577e+07
# C2    1.037335e+07
# C1    5.889610e+05
# Name: Mining and quarrying, dtype: float64

# %%
df_Mining.plot(kind='pie')
plt.show()

# %%
df_Other = df_by_quantile['Other services'].sum()
df_Other
# Out:
# quantile
# C4    15859015.0
# C3    12815417.0
# C2    36253657.0
# C1     8059922.0
# Name: Other services, dtype: float64

# %%
df_Other.plot(kind='pie')
plt.show()

# %%
df_PerCapita_GSDP = df_by_quantile['Per Capita GSDP (Rs.)'].sum()
df_PerCapita_GSDP
# Out:
# quantile
# C4     327547.0
# C3     691533.0
# C2    1264525.0
# C1     830922.0
# Name: Per Capita GSDP (Rs.), dtype: float64

# %%
df_PerCapita_GSDP.plot(kind='pie')
plt.show()

# %%
df_Population = df_by_quantile["Population ('00)"].sum()
df_Population
# Out:
# quantile
# C4    4683673.0
# C3    2031623.0
# C2    4036763.0
# C1     627743.0
# Name: Population ('00), dtype: float64

# %%
df_Population.plot(kind='pie')
plt.show()

# %%
df_PublicAdmin = df_by_quantile["Public administration"].sum()
df_PublicAdmin
# Out:
# quantile
# C4    13486630.0
# C3     7927173.0
# C2    18567815.0
# C1     3571292.0
# Name: Public administration, dtype: float64

# %%
df_PublicAdmin.plot(kind='pie')
plt.show()

# %%
df_Railways = df_by_quantile["Railways"].sum()
df_Railways
# Out:
# quantile
# C4    3305106.0
# C3    1390209.0
# C2    2494518.0
# C1     587419.0
# Name: Railways, dtype: float64

# %%
df_Railways.plot(kind='pie')
plt.show()

# %%
df_RealEstate = df_by_quantile["Real estate, ownership of dwelling & professional services"].sum()
df_RealEstate
# Out:
# quantile
# C4    24177534.0
# C3    16224118.0
# C2    92121446.0
# C1    14740245.0
# Name: Real estate, ownership of dwelling & professional services, dtype: float64

# %%
df_RealEstate.plot(kind='pie')
plt.show()

# %%
df_Road_transport = df_by_quantile["Road transport"].sum()
df_Road_transport
# Out:
# quantile
# C4    7.803560e+06
# C3    1.180633e+07
# C2    2.018334e+07
# C1    1.533818e+06
# Name: Road transport, dtype: float64

# %%
df_Road_transport.plot(kind='pie')
plt.show()

# %%
df_TransportServices = df_by_quantile["Services incidental to transport"].sum()
df_TransportServices
# Out:
# quantile
# C4    2.752330e+05
# C3    6.284852e+06
# C2    1.735162e+06
# C1    2.811080e+05
# Name: Services incidental to transport, dtype: float64

# %%
df_TransportServices.plot(kind='pie')
plt.show()

# %%
df_Storage = df_by_quantile["Storage"].sum()
df_Storage
# Out:
# quantile
# C4    5.556282e+06
# C3    7.539300e+04
# C2    3.685150e+05
# C1    1.810600e+04
# Name: Storage, dtype: float64

# %%
df_Storage.plot(kind='pie')
plt.show()

# %%
df_Subsidies = df_by_quantile["Subsidies on products"].sum()
df_Subsidies
# Out:
# quantile
# C4     8459602.0
# C3     6779982.0
# C2    13005659.0
# C1     1970502.0
# Name: Subsidies on products, dtype: float64

# %%
df_Subsidies.plot(kind='pie')
plt.show()

# %%
df_BasicGSVA = df_by_quantile["TOTAL GSVA at basic prices"].sum()
df_BasicGSVA
# Out:
# quantile
# C4    219788780.0
# C3    167623415.0
# C2    527484069.0
# C1     93126678.0
# Name: TOTAL GSVA at basic prices, dtype: float64

# %%
df_BasicGSVA.plot(kind='pie')
plt.show()

# %%
df_Taxes = df_by_quantile["Taxes on Products"].sum()
df_Taxes
# Out:
# quantile
# C4    21922888.00
# C3    17122953.00
# C2    71902042.04
# C1    10774501.00
# Name: Taxes on Products, dtype: float64

# %%
df_Taxes.plot(kind='pie')
plt.show()

# %%
df_Trade = df_by_quantile["Trade & repair services"].sum()
df_Trade
# Out:
# quantile
# C4    25581239.0
# C3    15953349.0
# C2    55252334.0
# C1     5225900.0
# Name: Trade & repair services, dtype: float64

# %%
df_Trade.plot(kind='pie')
plt.show()

# %%
df_Trade_Hotel = df_by_quantile["Trade, repair, hotels and restaurants"].sum()
df_Trade_Hotel
# Out:
# quantile
# C4    27484595.0
# C3    17245309.0
# C2    61238862.0
# C1    13995159.0
# Name: Trade, repair, hotels and restaurants, dtype: float64

# %%
df_Trade_Hotel.plot(kind='pie')
plt.show()

# %%
df_BroadCasting = df_by_quantile["Transport, storage, communication & services related to broadcasting"].sum()
df_BroadCasting
# Out:
# quantile
# C4    16191800.0
# C3    12231484.0
# C2    33749808.0
# C1     6818560.0
# Name: Transport, storage, communication & services related to broadcasting, dtype: float64

# %%
df_BroadCasting.plot(kind='pie')
plt.show()

# %%
df_Water = df_by_quantile["Water transport"].sum()
df_Water
# Out:
# quantile
# C4    5.341753e+06
# C3    1.081416e+07
# C2    1.098688e+07
# C1    5.379118e+06
# Name: Water transport, dtype: float64

# %%
df_Water.plot(kind='pie')
plt.show()

# %% [markdown]
# # Part-II: GDP and Education

# %% [markdown]
# ### Analyse if there is any correlation of GDP per capita with dropout rates in education (primary, upper primary and secondary) for the year 2014-2015 for the states.

# %%
df_dropOut = pd.read_csv('C:/Users/User/Desktop/practice set/GDP Analysis/copy data 2/rs_session243_au570_1.1.csv')
df_dropOut.head()
# Out:
#   Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0       1              A & N Islands                 0.68
# 1       2             Andhra Pradesh                 3.18
# 2       3          Arunachal Pradesh                15.16
# 3       4                      Assam                 6.24
# 4       5                      Bihar                  NaN
#
#    Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                 1.21                   0.51                       1.23
# 1                 4.35                   6.72                       3.36
# 2                10.89                  10.82                       7.47
# 3                 7.44                  15.36                       7.20
# 4                 2.09                    NaN                        NaN
#
#    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                       0.51                       1.69
# 1                       3.78                       5.20
# ...

# %% [markdown]
# #### renaming column 'Level of Education - State' to 'States'

# %%
df_dropOut = df_dropOut.rename(index=str, columns={"Level of Education - State": "States"})

# %% [markdown]
# #### selecting primary, upper primary and secondary columns for the duration 2014-15

# %%
df_dropOut = df_dropOut.loc[:,['States', 'Primary - 2014-2015', 'Upper Primary - 2014-2015', 'Secondary - 2014-2015']]

# %%
df_dropOut.head()
# Out:
#               States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      A & N Islands                 1.21                       1.69
# 1     Andhra Pradesh                 4.35                       5.20
# 2  Arunachal Pradesh                10.89                       6.71
# 3              Assam                 7.44                      10.51
# 4              Bihar                 2.09                       4.08
#
#    Secondary - 2014-2015
# 0                   9.87
# 1                  15.71
# 2                  17.11
# 3                  27.06
# 4                  25.90

# %% [markdown]
# #### imputing the NaN values with the mean

# %%
df_dropOut.isnull().sum()
# Out:
# States                       0
# Primary - 2014-2015          4
# Upper Primary - 2014-2015    2
# Secondary - 2014-2015        1
# dtype: int64

# %%
df_dropOut.describe()
# Out:
#        Primary - 2014-2015  Upper Primary - 2014-2015  Secondary - 2014-2015
# count            33.000000                  35.000000              36.000000
# mean              4.919394                   3.992571              17.294806
# std               4.990541                   2.639329               6.912640
# min               0.200000                   0.070000               6.070000
# 25%               1.210000                   1.890000              12.095000
# 50%               3.070000                   3.850000              16.330000
# 75%               7.080000                   5.625000              22.410000
# max              19.410000                  10.510000              32.270000

# %%
df_dropOut = df_dropOut.fillna(df_dropOut.mean())
df_dropOut.head()
# Out:
#               States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      A & N Islands                 1.21                       1.69
# 1     Andhra Pradesh                 4.35                       5.20
# 2  Arunachal Pradesh                10.89                       6.71
# 3              Assam                 7.44                      10.51
# 4              Bihar                 2.09                       4.08
#
#    Secondary - 2014-2015
# 0                   9.87
# 1                  15.71
# 2                  17.11
# 3                  27.06
# 4                  25.90

# %%
df_dropOut.isnull().sum()
# Out:
# States                       0
# Primary - 2014-2015          0
# Upper Primary - 2014-2015    0
# Secondary - 2014-2015        0
# dtype: int64

# %% [markdown]
# #### merging with GSDP of 2014-15

# %%
GSVA_df.head()
# Out:
#   S.No.                               Item    2011-12     2012-13     2013-14  \
# 0     1  Agriculture, forestry and fishing  9400805.0  11186428.0  12895568.0
# 1   1.1                              Crops  5204052.0   6123041.0   7114707.0
# 2   1.2                          Livestock  2758776.0   3358438.0   3643026.0
# 3   1.3               Forestry and logging   250314.0    253029.0    280493.0
# 4   1.4            Fishing and aquaculture  1187663.0   1451920.0   1857342.0
#
#       2014-15     2015-16     2016-17          States
# 0  14819416.0  17326726.0  20386004.0  Andhra_Pradesh
# 1   7893514.0   8644285.0   9717089.0  Andhra_Pradesh
# 2   4309078.0   5155487.0   5979648.0  Andhra_Pradesh
# 3    346160.0    340550.0    335487.0  Andhra_Pradesh
# 4   2270664.0   3186404.0   4353780.0  Andhra_Pradesh

# %%
df_GSDP = GSVA_df.loc[:,[False, True, False, False, False, True, False, False, True]]
df_GSDP.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_GSDP = df_GSDP.fillna(df_GSDP.mean())
df_GSDP.head()
# Out:
#                                 Item     2014-15          States
# 0  Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# 1                              Crops   7893514.0  Andhra_Pradesh
# 2                          Livestock   4309078.0  Andhra_Pradesh
# 3               Forestry and logging    346160.0  Andhra_Pradesh
# 4            Fishing and aquaculture   2270664.0  Andhra_Pradesh

# %%
df_GSDP.set_index('Item',inplace = True)
df_GSDP.head()
# Out:
#                                       2014-15          States
# Item
# Agriculture, forestry and fishing  14819416.0  Andhra_Pradesh
# Crops                               7893514.0  Andhra_Pradesh
# Livestock                           4309078.0  Andhra_Pradesh
# Forestry and logging                 346160.0  Andhra_Pradesh
# Fishing and aquaculture             2270664.0  Andhra_Pradesh

# %%
df_GSDP = df_GSDP.loc['Per Capita GSDP (Rs.)',:]
df_GSDP.head()
# Out:
#                         2014-15             States
# Item
# Per Capita GSDP (Rs.)  104977.0     Andhra_Pradesh
# Per Capita GSDP (Rs.)  112718.0  Arunachal_Pradesh
# Per Capita GSDP (Rs.)   60621.0              Assam
# Per Capita GSDP (Rs.)   33954.0              Bihar
# Per Capita GSDP (Rs.)   86860.0       Chhattisgarh

# %% [markdown]
# #### merging

# %%
df = pd.merge(df_dropOut, df_GSDP, how='inner', on='States')
df.head()
# Out:
#     States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0    Assam                 7.44                      10.51
# 1    Bihar                 2.09                       4.08
# 2      Goa                 0.20                       0.07
# 3  Gujarat                 0.76                       6.41
# 4  Haryana                 0.41                       5.81
#
#    Secondary - 2014-2015   2014-15
# 0                  27.06   60621.0
# 1                  25.90   33954.0
# 2                  11.15  271793.0
# 3                  25.04  141263.0
# 4                  15.89  164077.0

# %% [markdown]
# #### renaming last column with GSDP 2014-15

# %%
df = df.rename(index=str, columns={'2014-15': 'GSDP 2014-15'})
df.head()
# Out:
#     States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0    Assam                 7.44                      10.51
# 1    Bihar                 2.09                       4.08
# 2      Goa                 0.20                       0.07
# 3  Gujarat                 0.76                       6.41
# 4  Haryana                 0.41                       5.81
#
#    Secondary - 2014-2015  GSDP 2014-15
# 0                  27.06       60621.0
# 1                  25.90       33954.0
# 2                  11.15      271793.0
# 3                  25.04      141263.0
# 4                  15.89      164077.0

# %% [markdown]
# #### setting States as an index

# %%
df = df.set_index('States')
df.head()
# Out:
#          Primary - 2014-2015  Upper Primary - 2014-2015  \
# States
# Assam                   7.44                      10.51
# Bihar                   2.09                       4.08
# Goa                     0.20                       0.07
# Gujarat                 0.76                       6.41
# Haryana                 0.41                       5.81
#
#          Secondary - 2014-2015  GSDP 2014-15
# States
# Assam                    27.06       60621.0
# Bihar                    25.90       33954.0
# Goa                      11.15      271793.0
# Gujarat                  25.04      141263.0
# Haryana                  15.89      164077.0

# %% [markdown]
# #### plotting graph

# %%
df_corr = df.corr()
df_corr.head()
# Out:
#                            Primary - 2014-2015  Upper Primary - 2014-2015  \
# Primary - 2014-2015                   1.000000                   0.385616
# Upper Primary - 2014-2015             0.385616                   1.000000
# Secondary - 2014-2015                -0.032575                   0.429571
# GSDP 2014-15                         -0.445751                  -0.556941
#
#                            Secondary - 2014-2015  GSDP 2014-15
# Primary - 2014-2015                    -0.032575     -0.445751
# Upper Primary - 2014-2015               0.429571     -0.556941
# Secondary - 2014-2015                   1.000000     -0.524211
# GSDP 2014-15                           -0.524211      1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df_corr, cmap='YlGnBu', annot=True)
plt.show()

# %% [markdown]
# ### Write the key insights you observe from this data:

# %% [markdown]
# #### Primary , Upper primary and Secondary education are inversely related to GDP Per Capita.
# #### GDP per Capita increases then education is decreasing
